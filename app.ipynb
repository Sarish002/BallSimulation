# %%
import package
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Example 1: The Classic
package.App(False, 0, 0, False, 50, 180, 1, 0.2, False, False, [], False, False, 0)

# %%
# Color Change
package.App(False, 0, 0, False, 50, 180, 1, 0.2, True, False, [], False, False, 0)

# %%
# Size Changes
package.App(False, 0, 0, False, 50, 180, 1, 0.2, False, True, [], False, False, 0)

# %%
# Melody
package.App(False, 0, 0, False, 50, 180, 1, 0.2, False, False, ["Re", "Ga", "Ma", "Pa", "Ga", "Sa", "Re"], False, False, 0)

# %%
# Connections to visited points
package.App(False, 0, 0, False, 50, 180, 1, 0.2, False, False, [], True, False, 0)

# %%
# Changing Gravity: Representing Energy Loss
package.App(False, 0, 0, False, 50, 180, 1, 0.2, False, False, [], False, True, 0.002)

# %%
# Trail of previous positions
package.App(False, 0, 0, True, 50, 180, 1, 0.2, False, False, [], False, False, 0)

# %%
# Spinning Arc
package.App(True, 30, 0.2, False, 50, 180, 1, 0.2, False, False, [], False, False, 0)

# %%
# Changing Initial Color
package.App(False, 0, 0, False, 50, 0, 1, 0.2, False, False, [], False, False, 0)

# %%
# Using Multiple Balls
package.App(False, 0, 0, False, 50, 180, 5, 0.2, False, False, [], False, False, 0)

# %%
# Multiple Arguments
package.App(True, 30, 0.2, True, 75, 100, 3, 0.05, True, False, [], False, True, 0.002)
